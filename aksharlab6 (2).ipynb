# %%
import pandas as pd

import numpy as np
import warnings 
warnings.filterwarnings('ignore')

file_path=r"C:\Users\mpstme.student\Downloads\train_ctrUa4K.csv"

df=pd.read_csv(file_path)



(df.isnull().sum()/df.shape[0])*100



set_1={1,2,3}

print(set_1)



df.describe()



import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()




(df.isnull().sum()/df.shape[0])*100


set_1={1,2,3}

print(set_1)


df.describe()


import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()


df.Education.value_counts()


df.Education.value_counts(normalize=True)

sns.boxplot(df['ApplicantIncome'])


import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()


df.Education.value_counts(normalize=True)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# Graduate        0.781759
# Not Graduate    0.218241
# Name: Education, dtype: float64

# %%
(df.isnull().sum()/df.shape[0])*100



set_1={1,2,3}

print(set_1)



df.describe()



import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()




(df.isnull().sum()/df.shape[0])*100


set_1={1,2,3}

print(set_1)


df.describe()


import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()


df.Education.value_counts()


df.Education.value_counts(normalize=True)

sns.boxplot(df['ApplicantIncome'])


import seaborn as sns

sns.distplot(df['ApplicantIncome'])



df.Education.value_counts()


df.Education.value_counts(normalize=True)
# Out:
# {1, 2, 3}
# {1, 2, 3}
# Graduate        0.781759
# Not Graduate    0.218241
# Name: Education, dtype: float64

# %%
df['TotalIncome']=df['ApplicantIncome']+df['CoapplicantIncome']
print(df)
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
sns.distplot(np.log(df["TotalIncome"]))
# Out:
# <AxesSubplot:xlabel='TotalIncome', ylabel='Density'>

# %%
sns.distplot(np.sqrt(df["TotalIncome"]))
# Out:
# <AxesSubplot:xlabel='TotalIncome', ylabel='Density'>

# %%
df["TI_log"]=np.log(df["TotalIncome"])

# %% [raw]
# df.describe()

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History   TotalIncome      TI_log
# count      564.000000    614.000000  614.000000
# mean         0.842199   7024.705081    8.669414
# std          0.364878   6458.663872    0.545102
# min          0.000000   1442.000000    7.273786
# 25%          1.000000   4166.000000    8.334712
# ...

# %%
sns.boxplot(df['ApplicantIncome'])
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %%
m = np.mean(df["TI_log"])
sd = np.std(df["TI_log"])
p99 = np.percentile(df["TI_log"],99)
IQR = np.percentile(df["TI_log"],75)-np.percentile(df["TI_log"],25)

# %%
print(m)
# Out:
# 8.669413562902252

# %%
print(sd)
# Out:
# 0.5446574620738442

# %%
print(p99)
# Out:
# 10.530669145261063

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'TotalIncome', 'TI_log'],
#       dtype='object')

# %%
print(f"m + 3SD:{df.loc[df['TI_log']>m+3*sd,'Loan_ID'].count()}")
print(f"99 percentile:{df.loc[df['TI_log']>p99,'Loan_ID'].count()}")
print(f"IQR:{df.loc[df['TI_log']>(IQR+1.5*IQR),'Loan_ID'].count()}")
# Out:
# m + 3SD:9
# 99 percentile:7
# IQR:614

# %%
df["TI_log"]=np.where(df["TI_log"]>p99,p99,df["TI_log"])

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History   TotalIncome      TI_log
# count      564.000000    614.000000  614.000000
# mean         0.842199   7024.705081    8.666206
# std          0.364878   6458.663872    0.532448
# min          0.000000   1442.000000    7.273786
# 25%          1.000000   4166.000000    8.334712
# ...

# %%
sns.boxplot(df['TI_log'])
# Out:
# <AxesSubplot:xlabel='TI_log'>

# %%
sns.distplot(np.sqrt(df["TI_log"]))
# Out:
# <AxesSubplot:xlabel='TI_log', ylabel='Density'>

# %%
sns.displot(df['LoanAmount'])

# %%
sns.boxplot(df['LoanAmount'])
# Out:
# <AxesSubplot:xlabel='LoanAmount'>

# %%
df.LoanAmount.describe()
# Out:
# count    592.000000
# mean     146.412162
# std       85.587325
# min        9.000000
# 25%      100.000000
# 50%      128.000000
# 75%      168.000000
# max      700.000000
# Name: LoanAmount, dtype: float64

# %%
df.shape
# Out:
# (614, 15)

# %%
df.LoanAmount.value_counts()
# Out:
# 120.0    20
# 110.0    17
# 100.0    15
# 160.0    12
# 187.0    12
#          ..
# 240.0     1
# 214.0     1
# 59.0      1
# 166.0     1
# 253.0     1
# Name: LoanAmount, Length: 203, dtype: int64

# %%
m = np.mean(df["LoanAmount"])
sd = np.std(df["LoanAmount"])
p99 = np.percentile(df["LoanAmount"].dropna(),99)
IQR = np.percentile(df["LoanAmount"].dropna(),75)-np.percentile(df["LoanAmount"].dropna(),25)

# %% [markdown]
# print

# %%
m1=np.mean(df.LoanAmount.dropna())

# %%
print(f"m + 3SD:{df.loc[df['LoanAmount']>m+3*sd,'LoanAmount'].count()}")
print(f"99 percentile:{df.loc[df['LoanAmount']>p99,'LoanAmount'].count()}")
print(f"IQR:{df.loc[df['LoanAmount']>(IQR+1.5*IQR),'LoanAmount'].count()}")
# Out:
# m + 3SD:14
# 99 percentile:6
# IQR:143

# %%
sns.distplot(df['Loan_Amount_Term'])
# Out:
# <AxesSubplot:xlabel='Loan_Amount_Term', ylabel='Density'>

# %%
df.Loan_Amount_Term.value_counts(normalize=True)*100
# Out:
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: Loan_Amount_Term, dtype: float64

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
df.Credit_History.describe()
# Out:
# count    564.000000
# mean       0.842199
# std        0.364878
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: Credit_History, dtype: float64

# %%
df.Credit_History.value_counts()
# Out:
# 1.0    475
# 0.0     89
# Name: Credit_History, dtype: int64

# %%
df.Credit_History.fillna('Missing').value_counts(normalize=True)*100
# Out:
# 1.0        77.361564
# 0.0        14.495114
# Missing     8.143322
# Name: Credit_History, dtype: float64

# %%
df.Credit_History.fillna(0,inplace=True)

# %%
df.Credit_History.fillna('Missing').value_counts(normalize=True)*100
# Out:
# 1.0    77.361564
# 0.0    22.638436
# Name: Credit_History, dtype: float64

# %%
#lab 1-4

# %%
#lab 5

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
df.Gender.value_counts(normalize=True)*100
# Out:
# Male      81.364393
# Female    18.635607
# Name: Gender, dtype: float64

# %%
pd.crosstab(df.Gender.fillna('Missing'),df.Education)
# Out:
# Education  Graduate  Not Graduate
# Gender
# Female           92            20
# Male            376           113
# Missing          12             1

# %%
sns.violinplot(df.Gender.fillna('Missing'),df.ApplicantIncome)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='ApplicantIncome'>

# %%
pd.crosstab(df.Gender.fillna('Missing'),df.Married)
# Out:
# Married   No  Yes
# Gender
# Female    80   31
# Male     130  357
# Missing    3   10

# %%
df.loc[(df.Married=="Yes")&(df.Gender.isnull()),"Gender"]="Male"

# %%
df.Gender.value_counts(normalize=True)*100
# Out:
# Male      81.669394
# Female    18.330606
# Name: Gender, dtype: float64

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                3
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
df.Gender.fillna("Male",inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
pd.crosstab(df.Married.fillna('Missing'),df.Gender)
# Out:
# Gender   Female  Male
# Married
# Missing       1     2
# No           80   133
# Yes          31   367

# %%
df.loc[(df.Married.isnull())&(df.Gender=="Male"),"Married"]="Yes"

# %%
df.loc[(df.Married.isnull())&(df.Gender=="Female"),"Married"]="No"

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
sns.violinplot(df.Dependents.fillna('Missing'),df.TotalIncome)
# Out:
# <AxesSubplot:xlabel='Dependents', ylabel='TotalIncome'>

# %%
df.Dependents.fillna(2,inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
pd.crosstab(df.Self_Employed.fillna('Missing'),df.Education)
# Out:
# Education      Graduate  Not Graduate
# Self_Employed
# Missing              26             6
# No                  389           111
# Yes                  65            17

# %%
pd.crosstab(df.Self_Employed.fillna('Missing'),df.Gender)
# Out:
# Gender         Female  Male
# Self_Employed
# Missing             8    24
# No                 89   411
# Yes                15    67

# %%
sns.violinplot(df.Self_Employed.fillna('Missing'),df.LoanAmount)
# Out:
# <AxesSubplot:xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
pd.crosstab(df.Self_Employed.fillna('Missing'),df.Credit_History)
# Out:
# Credit_History  0.0  1.0
# Self_Employed
# Missing           7   25
# No              113  387
# Yes              19   63

# %%
df.Self_Employed.fillna("Yes",inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
sns.scatterplot(df.LoanAmount,df.ApplicantIncome,color="gold")
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='ApplicantIncome'>

# %%
sns.violinplot(df.Gender.fillna('Missing'),df.LoanAmount)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='LoanAmount'>

# %%
df.groupby(['Gender'])['LoanAmount'].mean()
# Out:
# Gender
# Female    126.697248
# Male      150.861284
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Education'])['LoanAmount'].mean()
# Out:
# Education
# Graduate        154.060215
# Not Graduate    118.409449
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Self_Employed'])['LoanAmount'].mean()
# Out:
# Self_Employed
# No     141.748963
# Yes    166.845455
# Name: LoanAmount, dtype: float64

# %%
df['LoanAmount'].fillna(df.groupby('Education')['LoanAmount'].transform('mean'),inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# TotalIncome           0
# TI_log                0
# dtype: int64

# %%
df.Loan_Amount_Term.value_counts(normalize=True)*100
# Out:
# 360.0    85.333333
# 180.0     7.333333
# 480.0     2.500000
# 300.0     2.166667
# 240.0     0.666667
# 84.0      0.666667
# 120.0     0.500000
# 60.0      0.333333
# 36.0      0.333333
# 12.0      0.166667
# Name: Loan_Amount_Term, dtype: float64

# %%
df.fillna(df.Loan_Amount_Term.mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# TotalIncome          0
# TI_log               0
# dtype: int64

# %%
df1 =df.copy()

# %%
df2 = pd.read_csv(r"C:\Users\mpstme.student\Downloads\test_lAUu6dG.csv")
df2.info
# Out:
# <bound method DataFrame.info of       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2['TotalIncome']=df2['ApplicantIncome']+df2['CoapplicantIncome']
print(df2)
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df2["TI_log"]=np.log(df2["TotalIncome"])

# %%
p99 = np.percentile(df["TI_log"],99)

# %%
print(f"99 percentile:{df.loc[df['LoanAmount']>p99,'LoanAmount'].count()}")
# Out:
# 99 percentile:613

# %%
print(p99)
# Out:
# 10.524361575660865

# %%
df2["TI_log"]=np.where(df2["TI_log"]>p99,p99,df2["TI_log"])

# %%
p99 = np.percentile(df2["LoanAmount"].dropna(),99)

# %%
print(p99)
# Out:
# 371.6999999999996

# %%
df2.Credit_History.fillna(0,inplace=True)

# %%
df2.loc[(df2.Married=="Yes")&(df2.Gender.isnull()),"Gender"]="Male"

# %%
df2.loc[(df2.Married.isnull())&(df2.Gender=="Male"),"Married"]="Yes"

# %%
df2.loc[(df2.Married.isnull())&(df2.Gender=="Female"),"Married"]="No"

# %%
df2.Dependents.fillna(2,inplace=True)

# %%
df2.Self_Employed.fillna("Yes",inplace=True)

# %%
df2['LoanAmount'].fillna(df2.groupby('Education')['LoanAmount'].transform('mean'),inplace=True)

# %%
df2.fillna(df.Loan_Amount_Term.mode()[0],inplace=True)

# %%
df2.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# TotalIncome          0
# TI_log               0
# dtype: int64

# %%
df1_1=df1.drop('Loan_ID',axis=1)

# %%
df2_2=df2.drop('Loan_ID',axis=1)

# %%
x_train=df1_1.drop('Loan_Status',axis=1)

# %%
y_train=df1_1['Loan_Status']

# %%
x_test=df2_2.copy()

# %%
x_train=pd.get_dummies(x_train,drop_first=True)

# %%
x_test=pd.get_dummies(x_test,drop_first=True)

# %%
df.shape
# Out:
# (614, 15)

# %%
x_train.drop(['TotalIncome',"ApplicantIncome","CoapplicantIncome"],axis=1,inplace=True)

# %%
x_test.drop(['TotalIncome',"ApplicantIncome","CoapplicantIncome"],axis=1,inplace=True)

# %%
x_test.shape
# Out:
# (367, 15)

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR=LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=LR.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3136\1409165003.py in <module>
# ----> 1 y_pred=LR.predict(x_test)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     423             Vector containing the class labels for each sample.
#     424         """
# --> 425         scores = self.decision_function(X)
#     426         if len(scores.shape) == 1:
#     427             indices = (scores > 0).astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_base.py in decision_function(self, X)
#     405         check_is_fitted(self)
#     406
# --> 407         X = self._validate_data(X, accept_sparse="csr", reset=False)
#     408         scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# ...

# %%
x_train.shape
# Out:
# (614, 14)

# %%
x_train.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TI_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
x_test.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TI_log',
#        'Gender_Female', 'Gender_Male', 'Married_Yes', 'Dependents_0',
#        'Dependents_1', 'Dependents_2', 'Dependents_3+',
#        'Education_Not Graduate', 'Self_Employed_Yes',
#        'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
x_test.drop(['Gender_Female'],axis=1,inplace=True)

# %%
y_pred=LR.predict(x_test)

# %%
print(y_pred)
# Out:
# ['Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y'
#  'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N'
#  'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y'
#  'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'Y' 'N' 'Y' 'Y'
#  'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y'
#  'N' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'N' 'Y'
#  'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'N' 'N' 'N' 'Y' 'Y' 'Y' 'N' 'N' 'Y'
#  'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'N' 'Y' 'N' 'N'
#  'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N'
#  'Y' 'Y' 'N' 'N' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'N' 'Y' 'Y' 'N' 'Y' 'N'
#  'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'N' 'Y' 'Y' 'N' 'Y'
#  'N' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y'
#  'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y' 'N' 'Y' 'Y' 'Y' 'Y'
# ...

# %%
predictions=pd.concat([df2.Loan_ID,pd.DataFrame(y_pred)],axis=1)

# %%
predictions.columns=["Loan_ID","Loan_Status"]

# %%
predictions.head()
# Out:
#     Loan_ID Loan_Status
# 0  LP001015           Y
# 1  LP001022           Y
# 2  LP001031           Y
# 3  LP001035           N
# 4  LP001051           Y

# %%
predictions.to_csv("Pred1_LR.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mpstme.student'

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
clf1=DecisionTreeClassifier()
clf1.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred1=clf1.predict(x_test)

# %%
x_train.shape
# Out:
# (614, 14)

# %%
x_test.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TI_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
y_pred1
# Out:
# array(['Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y',
#        'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y',
#        'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y',
#        'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y',
#        'N', 'N', 'N', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y',
#        'N', 'N', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'Y', 'N', 'N',
#        'Y', 'N', 'Y', 'Y', 'N', 'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'N', 'Y',
#        'Y', 'Y', 'Y', 'Y', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'Y', 'Y',
# ...

# %%
predictions_DT=pd.concat([df2.Loan_ID,pd.DataFrame(y_pred1)],axis=1)

# %%
predictions_DT.columns=["Loan_ID","Loan_Status"]

# %%
predictions_DT.to_csv("Pred1_dt.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mpstme.student'

# %%
x_train.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TI_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
x_test.columns
# Out:
# Index(['LoanAmount', 'Loan_Amount_Term', 'Credit_History', 'TI_log',
#        'Gender_Male', 'Married_Yes', 'Dependents_0', 'Dependents_1',
#        'Dependents_2', 'Dependents_3+', 'Education_Not Graduate',
#        'Self_Employed_Yes', 'Property_Area_Semiurban', 'Property_Area_Urban'],
#       dtype='object')

# %%
sudo pip install XGboost
# Out:
#   File "C:\Users\mpstme.student\AppData\Local\Temp\ipykernel_3136\2900403318.py", line 1
#     sudo pip install XGboost
#          ^
# SyntaxError: invalid syntax

# %%
from xgboost import XGBClassifier
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3136\3582011365.py in <module>
# ----> 1 from xgboost import XGBClassifier
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
rf1=RandomForestClassifier()
rf1.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2=rf1.predict(x_test)

# %%
predictions_FT=pd.concat([df2.Loan_ID,pd.DataFrame(y_pred2)],axis=1)

# %%
predictions_FT.columns=["Loan_ID","Loan_Status"]

# %%
predictions_FT.to_csv("Pred1_ft.csv",index=False)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\mpstme.student'
